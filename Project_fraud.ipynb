# %%
  # !pip install --upgrade xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Collecting xgboost
#   Downloading xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.3)
# Downloading xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 5.4 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.4
#     Uninstalling xgboost-2.1.4:
#       Successfully uninstalled xgboost-2.1.4
# Successfully installed xgboost-3.0.2

# %%
# !pip uninstall -y xgboost
# !pip install xgboost==1.7.6
# Out:
# Found existing installation: xgboost 2.1.4
# Uninstalling xgboost-2.1.4:
#   Successfully uninstalled xgboost-2.1.4
# Collecting xgboost==1.7.6
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost==1.7.6) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost==1.7.6) (1.15.3)
# Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 4.6 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.6

# %%
import pandas as pd
import numpy as np
import gc
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier

# Load Data
print("Loading data...")
train_trans = pd.read_csv("train_transaction.csv")
train_id = pd.read_csv("train_identity.csv")
test_trans = pd.read_csv("test_transaction.csv")
test_id = pd.read_csv("test_identity.csv")

train_df = train_trans.merge(train_id, on='TransactionID', how='left')
test_df = test_trans.merge(test_id, on='TransactionID', how='left')
print(f"Train shape: {train_df.shape} | Test shape: {test_df.shape}")

y = train_df['isFraud'].values
train_df = train_df.drop(columns=['TransactionID', 'isFraud'])
test_ids = test_df['TransactionID'].values
test_df = test_df.drop(columns=['TransactionID'])

# Preprocessing & Feature Reduction

print("Filling missing values and encoding...")
for df in [train_df, test_df]:
    for col in df.select_dtypes(include='number').columns:
        df[col] = df[col].fillna(df[col].median())
    for col in df.select_dtypes(include=['object', 'category']).columns:
        df[col] = df[col].fillna('missing').astype('category').cat.codes


shared_cols = train_df.columns.intersection(test_df.columns)
train_df = train_df[shared_cols]
test_df = test_df[shared_cols]


var_thresh = VarianceThreshold(threshold=0.01)
var_thresh.fit(train_df)
selected_cols = train_df.columns[var_thresh.get_support()]
train_df = train_df[selected_cols]
test_df = test_df[selected_cols]


corr_matrix = train_df.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [col for col in upper.columns if any(upper[col] > 0.95)]
train_df.drop(columns=to_drop, inplace=True)
test_df.drop(columns=to_drop, inplace=True)


rf = RandomForestClassifier(n_estimators=50, max_depth=5, n_jobs=-1, random_state=42)
rf.fit(train_df, y)
importances = rf.feature_importances_

imp_df = pd.DataFrame({'feature': train_df.columns, 'importance': importances})
imp_df = imp_df.sort_values(by='importance', ascending=False).head(100)
top_features = imp_df['feature'].tolist()


with open('selected_features.txt', 'w') as f:
    for feat in top_features:
        f.write(f"{feat}\n")

#
X = train_df[top_features]
X_test = test_df[top_features]
del train_df, test_df, rf, importances
gc.collect()

# AutoFeat Feature Engineering 
print("\nRunning AutoFeat to generate new features...")

from autofeat import AutoFeatClassifier

af_model = AutoFeatClassifier(verbose=1, featsel_runs=1)
X_af = af_model.fit_transform(X, y)
X_test_af = af_model.transform(X_test)

print(f"Original feature count: {X.shape[1]}")
print(f"New AutoFeat-enhanced feature count: {X_af.shape[1]}")


# Train XGBoost Model
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

xgb_clf = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='auc',
    use_label_encoder=False,
    tree_method='hist',
    random_state=42
)

xgb_clf.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=20,
    verbose=True
)




val_preds = xgb_clf.predict_proba(X_val)[:, 1]
val_auc = roc_auc_score(y_val, val_preds)
print(f"\nValidation ROC AUC: {val_auc:.4f}")

# STEP 4: Predict on Test Data 
print("Predicting on test set...")
test_preds = xgb_clf.predict_proba(X_test)[:, 1]

submission = pd.DataFrame({
    'TransactionID': test_ids,
    'isFraud': test_preds
})
submission.to_csv("xgb_submission.csv", index=False)
print("Submission saved to 'xgb_submission.csv'")
# Out:
# Loading data...
# Train shape: (52143, 434) | Test shape: (54450, 433)
# Filling missing values and encoding...
# Aligning train/test columns before feature reduction...
# Removing low-variance features...
# Removing highly correlated features...
# Selecting top 100 features with RandomForest...
# Training XGBoost...
# [0]	validation_0-auc:0.78258
# [1]	validation_0-auc:0.78081
# [2]	validation_0-auc:0.78355
# [3]	validation_0-auc:0.78274
# [4]	validation_0-auc:0.78354
# [5]	validation_0-auc:0.79693
# [6]	validation_0-auc:0.81865
# [7]	validation_0-auc:0.81653
# [8]	validation_0-auc:0.81926
# [9]	validation_0-auc:0.81925
# [10]	validation_0-auc:0.82034
# [11]	validation_0-auc:0.82219
# [12]	validation_0-auc:0.82174
# [13]	validation_0-auc:0.82209
# [14]	validation_0-auc:0.82393
# [15]	validation_0-auc:0.84255
# [16]	validation_0-auc:0.84681
# [17]	validation_0-auc:0.84934
# [18]	validation_0-auc:0.85056
# [19]	validation_0-auc:0.85330
# [20]	validation_0-auc:0.85483
# [21]	validation_0-auc:0.85513
# [22]	validation_0-auc:0.85558
# [23]	validation_0-auc:0.85599
# [24]	validation_0-auc:0.85652
# [25]	validation_0-auc:0.85899
# [26]	validation_0-auc:0.85886
# [27]	validation_0-auc:0.85797
# [28]	validation_0-auc:0.85898
# [29]	validation_0-auc:0.85990
# [30]	validation_0-auc:0.85964
# [31]	validation_0-auc:0.86024
# [32]	validation_0-auc:0.86122
# [33]	validation_0-auc:0.86244
# [34]	validation_0-auc:0.86214
# [35]	validation_0-auc:0.86296
# [36]	validation_0-auc:0.86325
# [37]	validation_0-auc:0.86368
# [38]	validation_0-auc:0.86346
# [39]	validation_0-auc:0.86353
# [40]	validation_0-auc:0.86519
# [41]	validation_0-auc:0.86551
# [42]	validation_0-auc:0.86608
# [43]	validation_0-auc:0.86700
# [44]	validation_0-auc:0.86711
# [45]	validation_0-auc:0.86777
# [46]	validation_0-auc:0.86802
# [47]	validation_0-auc:0.86866
# [48]	validation_0-auc:0.86891
# [49]	validation_0-auc:0.86969
# [50]	validation_0-auc:0.86954
# [51]	validation_0-auc:0.87003
# [52]	validation_0-auc:0.87023
# [53]	validation_0-auc:0.87032
# [54]	validation_0-auc:0.87063
# [55]	validation_0-auc:0.87113
# [56]	validation_0-auc:0.87155
# [57]	validation_0-auc:0.87399
# [58]	validation_0-auc:0.87434
# [59]	validation_0-auc:0.87717
# [60]	validation_0-auc:0.87696
# [61]	validation_0-auc:0.87731
# [62]	validation_0-auc:0.87782
# [63]	validation_0-auc:0.87824
# [64]	validation_0-auc:0.88151
# [65]	validation_0-auc:0.88150
# [66]	validation_0-auc:0.88158
# [67]	validation_0-auc:0.88198
# [68]	validation_0-auc:0.88237
# [69]	validation_0-auc:0.88339
# [70]	validation_0-auc:0.88359
# [71]	validation_0-auc:0.88393
# [72]	validation_0-auc:0.88387
# [73]	validation_0-auc:0.88409
# [74]	validation_0-auc:0.88474
# [75]	validation_0-auc:0.88447
# [76]	validation_0-auc:0.88554
# [77]	validation_0-auc:0.88553
# [78]	validation_0-auc:0.88622
# [79]	validation_0-auc:0.88634
# [80]	validation_0-auc:0.88663
# [81]	validation_0-auc:0.88713
# [82]	validation_0-auc:0.88837
# [83]	validation_0-auc:0.88883
# [84]	validation_0-auc:0.89052
# [85]	validation_0-auc:0.89065
# [86]	validation_0-auc:0.89103
# [87]	validation_0-auc:0.89254
# [88]	validation_0-auc:0.89302
# [89]	validation_0-auc:0.89332
# [90]	validation_0-auc:0.89391
# [91]	validation_0-auc:0.89472
# [92]	validation_0-auc:0.89441
# [93]	validation_0-auc:0.89462
# [94]	validation_0-auc:0.89512
# [95]	validation_0-auc:0.89565
# [96]	validation_0-auc:0.89563
# [97]	validation_0-auc:0.89575
# [98]	validation_0-auc:0.89563
# [99]	validation_0-auc:0.89615
# [100]	validation_0-auc:0.89606
# [101]	validation_0-auc:0.89623
# [102]	validation_0-auc:0.89661
# [103]	validation_0-auc:0.89694
# [104]	validation_0-auc:0.89765
# [105]	validation_0-auc:0.89835
# [106]	validation_0-auc:0.89836
# [107]	validation_0-auc:0.89824
# [108]	validation_0-auc:0.89811
# [109]	validation_0-auc:0.89858
# [110]	validation_0-auc:0.89867
# [111]	validation_0-auc:0.89873
# [112]	validation_0-auc:0.89870
# [113]	validation_0-auc:0.89845
# [114]	validation_0-auc:0.89903
# [115]	validation_0-auc:0.89929
# [116]	validation_0-auc:0.90012
# [117]	validation_0-auc:0.90025
# [118]	validation_0-auc:0.90028
# [119]	validation_0-auc:0.90064
# [120]	validation_0-auc:0.90081
# [121]	validation_0-auc:0.90082
# [122]	validation_0-auc:0.90143
# [123]	validation_0-auc:0.90166
# [124]	validation_0-auc:0.90206
# [125]	validation_0-auc:0.90229
# [126]	validation_0-auc:0.90255
# [127]	validation_0-auc:0.90281
# [128]	validation_0-auc:0.90272
# [129]	validation_0-auc:0.90241
# [130]	validation_0-auc:0.90262
# [131]	validation_0-auc:0.90289
# [132]	validation_0-auc:0.90315
# [133]	validation_0-auc:0.90325
# [134]	validation_0-auc:0.90331
# [135]	validation_0-auc:0.90360
# [136]	validation_0-auc:0.90383
# [137]	validation_0-auc:0.90381
# [138]	validation_0-auc:0.90395
# [139]	validation_0-auc:0.90413
# [140]	validation_0-auc:0.90422
# [141]	validation_0-auc:0.90421
# [142]	validation_0-auc:0.90438
# [143]	validation_0-auc:0.90446
# [144]	validation_0-auc:0.90465
# [145]	validation_0-auc:0.90450
# [146]	validation_0-auc:0.90459
# [147]	validation_0-auc:0.90491
# [148]	validation_0-auc:0.90493
# [149]	validation_0-auc:0.90517
# [150]	validation_0-auc:0.90542
# [151]	validation_0-auc:0.90544
# [152]	validation_0-auc:0.90573
# [153]	validation_0-auc:0.90591
# [154]	validation_0-auc:0.90596
# [155]	validation_0-auc:0.90613
# [156]	validation_0-auc:0.90609
# [157]	validation_0-auc:0.90615
# [158]	validation_0-auc:0.90618
# [159]	validation_0-auc:0.90662
# [160]	validation_0-auc:0.90660
# [161]	validation_0-auc:0.90684
# [162]	validation_0-auc:0.90699
# [163]	validation_0-auc:0.90712
# [164]	validation_0-auc:0.90739
# [165]	validation_0-auc:0.90747
# [166]	validation_0-auc:0.90753
# [167]	validation_0-auc:0.90754
# [168]	validation_0-auc:0.90758
# [169]	validation_0-auc:0.90759
# [170]	validation_0-auc:0.90791
# [171]	validation_0-auc:0.90780
# [172]	validation_0-auc:0.90808
# [173]	validation_0-auc:0.90820
# [174]	validation_0-auc:0.90832
# [175]	validation_0-auc:0.90841
# [176]	validation_0-auc:0.90835
# [177]	validation_0-auc:0.90862
# [178]	validation_0-auc:0.90889
# [179]	validation_0-auc:0.90890
# [180]	validation_0-auc:0.90888
# [181]	validation_0-auc:0.90896
# [182]	validation_0-auc:0.90936
# [183]	validation_0-auc:0.90928
# [184]	validation_0-auc:0.90950
# [185]	validation_0-auc:0.90949
# [186]	validation_0-auc:0.90962
# [187]	validation_0-auc:0.90949
# [188]	validation_0-auc:0.90942
# [189]	validation_0-auc:0.90942
# [190]	validation_0-auc:0.90947
# [191]	validation_0-auc:0.90969
# [192]	validation_0-auc:0.91001
# [193]	validation_0-auc:0.90999
# [194]	validation_0-auc:0.91000
# [195]	validation_0-auc:0.91006
# [196]	validation_0-auc:0.91008
# [197]	validation_0-auc:0.91058
# [198]	validation_0-auc:0.91112
# [199]	validation_0-auc:0.91142
# [200]	validation_0-auc:0.91166
# [201]	validation_0-auc:0.91147
# [202]	validation_0-auc:0.91224
# [203]	validation_0-auc:0.91234
# [204]	validation_0-auc:0.91256
# [205]	validation_0-auc:0.91256
# [206]	validation_0-auc:0.91235
# [207]	validation_0-auc:0.91246
# [208]	validation_0-auc:0.91267
# [209]	validation_0-auc:0.91273
# [210]	validation_0-auc:0.91278
# [211]	validation_0-auc:0.91290
# [212]	validation_0-auc:0.91285
# [213]	validation_0-auc:0.91305
# [214]	validation_0-auc:0.91302
# [215]	validation_0-auc:0.91308
# [216]	validation_0-auc:0.91305
# [217]	validation_0-auc:0.91311
# [218]	validation_0-auc:0.91314
# [219]	validation_0-auc:0.91325
# [220]	validation_0-auc:0.91373
# [221]	validation_0-auc:0.91379
# [222]	validation_0-auc:0.91389
# [223]	validation_0-auc:0.91405
# [224]	validation_0-auc:0.91406
# [225]	validation_0-auc:0.91391
# [226]	validation_0-auc:0.91374
# [227]	validation_0-auc:0.91402
# [228]	validation_0-auc:0.91418
# [229]	validation_0-auc:0.91421
# [230]	validation_0-auc:0.91431
# [231]	validation_0-auc:0.91497
# [232]	validation_0-auc:0.91512
# [233]	validation_0-auc:0.91510
# [234]	validation_0-auc:0.91519
# [235]	validation_0-auc:0.91523
# [236]	validation_0-auc:0.91521
# [237]	validation_0-auc:0.91536
# [238]	validation_0-auc:0.91555
# [239]	validation_0-auc:0.91561
# [240]	validation_0-auc:0.91566
# [241]	validation_0-auc:0.91577
# [242]	validation_0-auc:0.91582
# [243]	validation_0-auc:0.91579
# [244]	validation_0-auc:0.91565
# [245]	validation_0-auc:0.91573
# [246]	validation_0-auc:0.91577
# [247]	validation_0-auc:0.91590
# [248]	validation_0-auc:0.91618
# [249]	validation_0-auc:0.91616
# [250]	validation_0-auc:0.91630
# [251]	validation_0-auc:0.91634
# [252]	validation_0-auc:0.91667
# [253]	validation_0-auc:0.91670
# [254]	validation_0-auc:0.91679
# [255]	validation_0-auc:0.91675
# [256]	validation_0-auc:0.91685
# [257]	validation_0-auc:0.91701
# [258]	validation_0-auc:0.91721
# [259]	validation_0-auc:0.91714
# [260]	validation_0-auc:0.91722
# [261]	validation_0-auc:0.91739
# [262]	validation_0-auc:0.91751
# [263]	validation_0-auc:0.91735
# [264]	validation_0-auc:0.91736
# [265]	validation_0-auc:0.91739
# [266]	validation_0-auc:0.91738
# [267]	validation_0-auc:0.91742
# [268]	validation_0-auc:0.91763
# [269]	validation_0-auc:0.91787
# [270]	validation_0-auc:0.91787
# [271]	validation_0-auc:0.91789
# [272]	validation_0-auc:0.91808
# [273]	validation_0-auc:0.91798
# [274]	validation_0-auc:0.91807
# [275]	validation_0-auc:0.91799
# [276]	validation_0-auc:0.91796
# [277]	validation_0-auc:0.91790
# [278]	validation_0-auc:0.91799
# [279]	validation_0-auc:0.91806
# [280]	validation_0-auc:0.91813
# [281]	validation_0-auc:0.91823
# [282]	validation_0-auc:0.91823
# [283]	validation_0-auc:0.91821
# [284]	validation_0-auc:0.91827
# [285]	validation_0-auc:0.91815
# [286]	validation_0-auc:0.91827
# [287]	validation_0-auc:0.91825
# [288]	validation_0-auc:0.91830
# [289]	validation_0-auc:0.91815
# [290]	validation_0-auc:0.91825
# [291]	validation_0-auc:0.91818
# [292]	validation_0-auc:0.91823
# [293]	validation_0-auc:0.91828
# [294]	validation_0-auc:0.91840
# [295]	validation_0-auc:0.91841
# [296]	validation_0-auc:0.91850
# [297]	validation_0-auc:0.91873
# [298]	validation_0-auc:0.91867
# [299]	validation_0-auc:0.91873
#
# Validation ROC AUC: 0.9187
# Predicting on test set...
# Submission saved to 'xgb_submission.csv'

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

params_grid = [
    {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 0.7},
    {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1},
    {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 15}
]


best_score = 0
best_model = None
best_params = None

for params in params_grid:
    print(f"\nTrying params: {params}")

    model = XGBClassifier(
        n_estimators=500,
        #subsample=0.8,
        #colsample_bytree=0.8,
        eval_metric='auc',
        use_label_encoder=False,
        tree_method='hist',
        random_state=42,
        **params
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=20,
        verbose=False
    )

    preds = model.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, preds)
    print(f"AUC: {auc:.4f}")

    if auc > best_score:
        best_score = auc
        best_model = model
        best_params = params

print(f"\n✅ Best AUC: {best_score:.4f}")
print(f"✅ Best Parameters: {best_params}")
# Out:
# Trying params: {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 0.7}
# AUC: 0.9130
#
# Trying params: {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# AUC: 0.9179
#
# Trying params: {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 15}
# AUC: 0.9217
#
# ✅ Best AUC: 0.9217
# ✅ Best Parameters: {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 15}
